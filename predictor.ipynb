# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("PassengerId", axis=1, inplace=True)
df.drop("Name", axis=1, inplace=True)

# %%
df = df.dropna(subset=["Embarked"])
df["Age"] = df["Age"].fillna(df["Age"].mean())
# Out:
# /var/folders/0c/b621szrx7v3chp8pdhqlntwc0000gn/T/ipykernel_14871/779885428.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df["Cabin"] = df["Cabin"].fillna(0)
df
# Out:
# /var/folders/0c/b621szrx7v3chp8pdhqlntwc0000gn/T/ipykernel_14871/2123715276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cabin"] = df["Cabin"].fillna(0)
#      Survived  Pclass     Sex        Age  SibSp  Parch            Ticket  \
# 0           0       3    male  22.000000      1      0         A/5 21171
# 1           1       1  female  38.000000      1      0          PC 17599
# 2           1       3  female  26.000000      0      0  STON/O2. 3101282
# 3           1       1  female  35.000000      1      0            113803
# 4           0       3    male  35.000000      0      0            373450
# ..        ...     ...     ...        ...    ...    ...               ...
# ...

# %%
df = pd.get_dummies(df, columns = ["Sex","Embarked"])
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3  22.000000      1      0         A/5 21171   7.2500
# 1           1       1  38.000000      1      0          PC 17599  71.2833
# 2           1       3  26.000000      0      0  STON/O2. 3101282   7.9250
# 3           1       1  35.000000      1      0            113803  53.1000
# 4           0       3  35.000000      0      0            373450   8.0500
# ..        ...     ...        ...    ...    ...               ...      ...
# 886         0       2  27.000000      0      0            211536  13.0000
# 887         1       1  19.000000      0      0            112053  30.0000
# 888         0       3  29.642093      1      2        W./C. 6607  23.4500
# 889         1       1  26.000000      0      0            111369  30.0000
# 890         0       3  32.000000      0      0            370376   7.7500
#
#     Cabin  Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# ...

# %%
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3  22.000000      1      0         A/5 21171   7.2500
# 1           1       1  38.000000      1      0          PC 17599  71.2833
# 2           1       3  26.000000      0      0  STON/O2. 3101282   7.9250
# 3           1       1  35.000000      1      0            113803  53.1000
# 4           0       3  35.000000      0      0            373450   8.0500
# ..        ...     ...        ...    ...    ...               ...      ...
# 886         0       2  27.000000      0      0            211536  13.0000
# 887         1       1  19.000000      0      0            112053  30.0000
# 888         0       3  29.642093      1      2        W./C. 6607  23.4500
# 889         1       1  26.000000      0      0            111369  30.0000
# 890         0       3  32.000000      0      0            370376   7.7500
#
#     Cabin  Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# ...

# %%
df["Cabin_Deck"] = df["Cabin"].str[0]
df.drop("Cabin", axis=1, inplace=True)
df = pd.get_dummies(df, columns = ["Cabin_Deck"])
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3  22.000000      1      0         A/5 21171   7.2500
# 1           1       1  38.000000      1      0          PC 17599  71.2833
# 2           1       3  26.000000      0      0  STON/O2. 3101282   7.9250
# 3           1       1  35.000000      1      0            113803  53.1000
# 4           0       3  35.000000      0      0            373450   8.0500
# ..        ...     ...        ...    ...    ...               ...      ...
# 886         0       2  27.000000      0      0            211536  13.0000
# 887         1       1  19.000000      0      0            112053  30.0000
# 888         0       3  29.642093      1      2        W./C. 6607  23.4500
# 889         1       1  26.000000      0      0            111369  30.0000
# 890         0       3  32.000000      0      0            370376   7.7500
#
#      Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S  Cabin_Deck_A  \
# ...

# %%
pd.reset_option("display.max_rows", None)
df.drop("Ticket", axis=1, inplace=True)
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.000000      1      0   7.2500       False      True
# 1           1       1  38.000000      1      0  71.2833        True     False
# 2           1       3  26.000000      0      0   7.9250        True     False
# 3           1       1  35.000000      1      0  53.1000        True     False
# 4           0       3  35.000000      0      0   8.0500       False      True
# ..        ...     ...        ...    ...    ...      ...         ...       ...
# 886         0       2  27.000000      0      0  13.0000       False      True
# 887         1       1  19.000000      0      0  30.0000        True     False
# 888         0       3  29.642093      1      2  23.4500        True     False
# 889         1       1  26.000000      0      0  30.0000       False      True
# 890         0       3  32.000000      0      0   7.7500       False      True
#
# ...

# %%
result = np.array(df["Survived"])

df.drop("Survived", axis=1, inplace=True)

inputs = np.array(df)

# %%
model = LogisticRegression(solver="liblinear", random_state=0)
model.fit(inputs,result)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %%
model.score(inputs,result)
# Out:
# 0.8098987626546682

# %%
test_set = pd.read_csv("test.csv")
test_set["Survived"] = pd.read_csv("gender_submission.csv")["Survived"]
test_set
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
test_set.drop("Name", axis=1, inplace=True)
test_set.drop("PassengerId", axis=1, inplace=True)
test_set.drop("Ticket", axis=1, inplace=True)

# %%
test_set["Cabin"] = test_set["Cabin"].fillna(0)
test_set = pd.get_dummies(test_set, columns=["Sex", "Embarked"], )
test_set.isnull().sum()
# Out:
# Pclass         0
# Age           86
# SibSp          0
# Parch          0
# Fare           1
# Cabin          0
# Survived       0
# Sex_female     0
# Sex_male       0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
test_set = test_set.dropna(subset=["Fare"])
test_set["Age"] = test_set["Age"].fillna(test_set["Age"].mean())

# %%
test_set["Cabin_Deck"] = test_set["Cabin"].str[0]
test_set.drop("Cabin", axis=1, inplace=True)
test_set = pd.get_dummies(test_set, columns = ["Cabin_Deck"])

# %%
test_set["Cabin_Deck_T"] = False

# %%
test_results = np.array(test_set["Survived"])
test_set.drop("Survived", axis=1, inplace=True)
test_set = np.array(test_set)

# %%
model.score(test_set,test_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.score(test_set,test_results)
#
# NameError: name 'model' is not defined
